# %%
import tensorflow as tf
mnist=tf.keras.datasets.mnist
(training_images,training_labels),(test_images,test_labels)=mnist.load_data()
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/tf-keras-datasets/mnist.npz
# 11493376/11490434 [==============================] - 0s 0us/step

# %%
training_images=training_images /255.0
test_images=test_images /255.0
model=tf.keras.models.Sequential([tf.keras.layers.Flatten(),
                                  tf.keras.layers.Dense(512,activation=tf.nn.relu),
                                  tf.keras.layers.Dense(10,activation=tf.nn.softmax)])

# %%
model.compile(optimizer=tf.keras.optimizers.Adam(),
              loss='sparse_categorical_crossentropy',
              metrics=['accuracy'])

# %%
model.fit(training_images,training_labels,epochs=5,batch_size=64)
# Out:
# Epoch 1/5
# 938/938 [==============================] - 4s 5ms/step - loss: 0.2283 - accuracy: 0.9348
# Epoch 2/5
# 938/938 [==============================] - 4s 4ms/step - loss: 0.0891 - accuracy: 0.9735
# Epoch 3/5
# 938/938 [==============================] - 4s 4ms/step - loss: 0.0566 - accuracy: 0.9828
# Epoch 4/5
# 938/938 [==============================] - 4s 4ms/step - loss: 0.0403 - accuracy: 0.9878
# Epoch 5/5
# 938/938 [==============================] - 4s 4ms/step - loss: 0.0287 - accuracy: 0.9912
